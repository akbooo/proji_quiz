# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('Proji - Sheet1.csv')

# %%
df.head()
# Out:
#                    Дата  Score Уровень  Lead Score  \
# 0  14.06.2026, 22:41:26    100  leader          35
# 1  14.06.2026, 23:16:16     94  leader          35
# 2  14.06.2026, 23:31:13    100  leader          35
# 3  14.06.2026, 23:53:42    100  leader          20
# 4  15.06.2026, 12:14:25     76  leader          82
#
#   Продажи и Клиентский сервис Рутинные процессы Данные и База знаний  \
# 0                         100               100                  100
# 1                          77               100                  100
# 2                         100               100                  100
# 3                         100               100                  100
# 4                          57                57                   85
#
#   Операционка и Прогнозы  Культура и Готовность команды Сильная зона  ...  \
# 0                    100                          100.0           ai  ...
# 1                    100                          100.0           ai  ...
# ...

# %%
df=df[df['Дата']>'19.06.2026']
df
# Out:
#                         Дата  Score          Уровень  Lead Score  \
# 39  2026-06-18T16:03:58.330Z    100         AI-Лидер         100
# 41  2026-06-18T16:06:42.516Z    100         AI-Лидер         100
# 49      19.06.2026, 13:13:02     37  point_potential          55
# 50      19.06.2026, 13:20:38     49  point_potential          45
# 51      19.06.2026, 13:22:47     39  point_potential          55
# 52      19.06.2026, 13:24:59     80        ai_leader          40
# 53      19.06.2026, 14:26:26     47  point_potential          35
# 54      19.06.2026, 14:28:23     49  point_potential          55
# 55      19.06.2026, 16:31:34     40  point_potential          15
# 56      19.06.2026, 16:31:52     86        ai_leader          40
# 57      19.06.2026, 16:32:06     68   transformation          25
# 58      19.06.2026, 16:32:29     77        ai_leader          40
# 59      19.06.2026, 16:32:33     57   transformation          45
# ...

# %%
df=df.iloc[8:]

# %%
df
# Out:
#                     Дата  Score          Уровень  Lead Score  \
# 55  19.06.2026, 16:31:34     40  point_potential          15
# 56  19.06.2026, 16:31:52     86        ai_leader          40
# 57  19.06.2026, 16:32:06     68   transformation          25
# 58  19.06.2026, 16:32:29     77        ai_leader          40
# 59  19.06.2026, 16:32:33     57   transformation          45
# 60  19.06.2026, 16:32:43     69   transformation          35
# 61  19.06.2026, 16:35:08     75        ai_leader          25
# 62  19.06.2026, 16:35:15     47  point_potential          45
# 63  19.06.2026, 16:35:57     71   transformation          35
# 64  19.06.2026, 16:37:40     62   transformation          55
# 65  19.06.2026, 19:37:10     64   transformation          55
# 66  19.06.2026, 19:37:10     64   transformation          55
# 67  20.06.2026, 01:56:38     59   transformation          25
# 68  20.06.2026, 10:27:59     55   transformation          55
# ...

# %%
friday=df.iloc[0:10]

# %%
friday
# Out:
#                     Дата  Score          Уровень  Lead Score  \
# 55  19.06.2026, 16:31:34     40  point_potential          15
# 56  19.06.2026, 16:31:52     86        ai_leader          40
# 57  19.06.2026, 16:32:06     68   transformation          25
# 58  19.06.2026, 16:32:29     77        ai_leader          40
# 59  19.06.2026, 16:32:33     57   transformation          45
# 60  19.06.2026, 16:32:43     69   transformation          35
# 61  19.06.2026, 16:35:08     75        ai_leader          25
# 62  19.06.2026, 16:35:15     47  point_potential          45
# 63  19.06.2026, 16:35:57     71   transformation          35
# 64  19.06.2026, 16:37:40     62   transformation          55
#
#    Продажи и Клиентский сервис Рутинные процессы Данные и База знаний  \
# 55                          40               100                   40
# 56                          70               100                  100
# 57                          20               100                   70
# ...

# %%
friday.columns
# Out:
# Index(['Дата', 'Score', 'Уровень', 'Lead Score', 'Продажи и Клиентский сервис',
#        'Рутинные процессы', 'Данные и База знаний', 'Операционка и Прогнозы',
#        'Культура и Готовность команды', 'Сильная зона', 'Слабые зоны', 'Сфера',
#        'Размер команды', 'Модель продаж', 'Стадия', 'Landing Path', 'Device',
#        'Language', 'Ответы (JSON)', 'Обратная связь (JSON)', 'ID'],
#       dtype='object')

# %%
friday.drop(columns=['Город', "Имя", 'Телефон', 'Компания', 'Email', 'UTM Source', 'UTM Medium', 'UTM Campaign', 
            'UTM Content', 'UTM Term', 'Referrer', 'ID.1'], inplace=True, axis=1)
# Out:
# C:\Users\Subbota\AppData\Local\Temp\ipykernel_26760\4210416170.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   friday.drop(columns=['Город', "Имя", 'Телефон', 'Компания', 'Email', 'UTM Source', 'UTM Medium', 'UTM Campaign',

# %%
friday.to_csv('friday.csv', index=False)

# %%
friday.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, 55 to 64
# Data columns (total 21 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Дата                           10 non-null     object
#  1   Score                          10 non-null     int64
#  2   Уровень                        10 non-null     object
#  3   Lead Score                     10 non-null     int64
#  4   Продажи и Клиентский сервис    10 non-null     object
#  5   Рутинные процессы              10 non-null     object
#  6   Данные и База знаний           10 non-null     object
#  7   Операционка и Прогнозы         10 non-null     object
#  8   Культура и Готовность команды  10 non-null     float64
#  9   Сильная зона                   10 non-null     object
#  10  Слабые зоны                    10 non-null     object
#  11  Сфера                          10 non-null     object
# ...
